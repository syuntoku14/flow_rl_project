# %%
import os, pickle
import numpy as np
from flow.multiagent_envs import MultiWaveAttenuationMergePOEnv
from flow.scenarios import MergeScenario
from flow.utils.registry import make_create_env
from flow.utils.rllib import FlowParamsEncoder
from flow.core.params import InFlows

from ray.tune import run_experiments
from ray.tune.experiment import Experiment, convert_to_experiment_list

import gym, ray
from ray.rllib.agents.ppo import PPOAgent, DEFAULT_CONFIG
from ray.tune.registry import register_env, register_trainable
from ray.tune.logger import pretty_print

benchmark_name = 'multi_merge'

# %%
num_rollouts = 60
num_cpus = 62
gae_lambda = 0.97
step_size = 5e-4
benchmark_name = 'multi_merge'
exp_name = 'buff_obs'
AGENT = 'PPO' # 'PPO' or 'DDPG' or 'HUMAN'
checkpoint = '50'
results_list = os.listdir('/headless/ray_results/' + exp_name)
# results_list

# %%
ray.init(num_cpus=num_cpus, include_webui=False, ignore_reinit_error=True)
# Out:
# Calling ray.init() again after it has already been called.

# %%
# get flow_params
benchmark = __import__(
    "flow.benchmarks.%s" % benchmark_name, fromlist=["flow_params"])
flow_params = benchmark.buffered_obs_flow_params

# inflow rate at the highway
FLOW_RATE = np.random.randint(1000, 2000)
FLOW_RATE_MERGE = np.random.randint(50, 150)
# percent of autonomous vehicles
RL_PENETRATION = 0.05 + np.random.rand() * 0.1

inflow = InFlows()
inflow.add(
    veh_type="human",
    edge="inflow_highway",
    vehs_per_hour=int((1 - RL_PENETRATION) * FLOW_RATE),
    #probability=FLOW_PROB,
    departLane="free",
    departSpeed=10)
inflow.add(
    veh_type="rl",
    edge="inflow_highway",
    vehs_per_hour=int(RL_PENETRATION * FLOW_RATE),
    #probability=FLOW_PROB_MERGE,
    departLane="free",
    departSpeed=10)
inflow.add(
    veh_type="human",
    edge="inflow_merge",
    vehs_per_hour=FLOW_RATE_MERGE,
    #probability=FLOW_PROB_RL,
    departLane="free",
    departSpeed=7.5)

# generate new flow_params
net = flow_params['net']
net.inflows = inflow

# flow_params['net'].inflows.get()
create_env, env_name = make_create_env(params=flow_params, version=0)

# Register as rllib env
register_env('Rondom'+env_name, create_env)

# %%
base = '/headless/ray_results/' + exp_name + '/' + \
    'PPO_MultiWaveAttenuationMergePOEnvBufferedObs-v0_[eta1, eta2, eta3]:[1.0, 0.2, 0.3]_t_min:10.0_7_2019-04-28_11-49-51_zkx7fvy'
config_path = base + '/params.pkl'
checkpoint_path = base + '/checkpoint_{}/checkpoint-{}'.format(checkpoint, checkpoint)

with open(config_path, mode='rb') as f:
    config = pickle.load(f)

# %%
exp_tag = {
    "run": AGENT,
    "env": 'Rondom'+env_name,
    "config": {
        **config
    },
    "checkpoint_freq": 20,
    "max_failures": 999,
    "stop": {
        "training_iteration": 55
    },
    "num_samples": 1,
    "restore": checkpoint_path
}

# %%
a = convert_to_experiment_list({'test':exp_tag})
a = a[0]
a.spec
# Out:
# {'checkpoint_at_end': False,
#  'checkpoint_freq': 20,
#  'config': {'batch_mode': 'truncate_episodes',
#   'callbacks': {'on_episode_end': <ray.tune.suggest.variant_generator.function at 0x7fb3838e58d0>,
#    'on_episode_start': <ray.tune.suggest.variant_generator.function at 0x7fb3838e5e80>,
#    'on_episode_step': <ray.tune.suggest.variant_generator.function at 0x7fb3838e5f60>,
#    'on_sample_end': None,
#    'on_train_result': None},
#   'clip_actions': False,
#   'clip_param': 0.3,
#   'clip_rewards': None,
#   'collect_metrics_timeout': 180,
#   'compress_observations': False,
#   'custom_resources_per_worker': {},
#   'entropy_coeff': 0.0,
#   'env': 'RondomMultiWaveAttenuationMergePOEnvBufferedObs-v0',
#   'env_config': {'flow_params': '{\n    "env": {\n        "additional_params": {\n            "FLOW_RATE": 2000,\n            "eta1": 1.0,\n            "eta2": 0.3,\n            "eta3": 0.3,\n            "max_accel": 3,\n            "max_decel": 3,\n            "reward_scale": 1.0,\n            "t_min": 7.0,\n            "target_velocity": 25\n        },\n        "evaluate": false,\n        "horizon": 1500,\n        "sims_per_step": 2,\n        "warmup_steps": 100\n    },\n    "env_name": "MultiWaveAttenuationMergePOEnvBufferedObs",\n    "exp_tag": "multi_merge",\n    "initial": {\n        "additional_params": {},\n        "bunching": 0,\n        "edges_distribution": "all",\n        "lanes_distribution": Infinity,\n        "min_gap": 0,\n        "perturbation": 0.0,\n        "shuffle": false,\n        "spacing": "uniform",\n        "x0": 0\n    },\n    "net": {\n        "additional_params": {\n            "highway_lanes": 1,\n            "merge_lanes": 1,\n            "merge_length": 100,\n            "post_merge_length": 100,\n            "pre_merge_length": 600,\n            "speed_limit": 30\n        },\n        "inflows": {\n            "_InFlows__flows": [\n                {\n                    "begin": 1,\n                    "departLane": "free",\n                    "departSpeed": 10,\n                    "edge": "inflow_highway",\n                    "end": 2000000.0,\n                    "name": "flow_0",\n                    "vehsPerHour": 1800.0,\n                    "vtype": "human"\n                },\n                {\n                    "begin": 1,\n                    "departLane": "free",\n                    "departSpeed": 10,\n                    "edge": "inflow_highway",\n                    "end": 2000000.0,\n                    "name": "flow_1",\n                    "vehsPerHour": 200.0,\n                    "vtype": "rl"\n                },\n                {\n                    "begin": 1,\n                    "departLane": "free",\n                    "departSpeed": 7.5,\n                    "edge": "inflow_merge",\n                    "end": 2000000.0,\n                    "name": "flow_2",\n                    "vehsPerHour": 100,\n                    "vtype": "human"\n                }\n            ],\n            "num_flows": 3\n        },\n        "netfile": null,\n        "no_internal_links": false,\n        "osm_path": null\n    },\n    "scenario": "MergeScenario",\n    "sim": {\n        "emission_path": null,\n        "lateral_resolution": null,\n        "no_step_log": true,\n        "num_clients": 1,\n        "overtake_right": false,\n        "port": null,\n        "print_warnings": true,\n        "pxpm": 2,\n        "render": false,\n        "restart_instance": true,\n        "save_render": false,\n        "seed": null,\n        "show_radius": false,\n        "sight_radius": 25,\n        "sim_step": 0.2,\n        "teleport_time": -1\n    },\n    "simulator": "traci",\n    "veh": [\n        {\n            "acceleration_controller": [\n                "SimCarFollowingController",\n                {}\n            ],\n            "car_following_params": {\n                "controller_params": {\n                    "accel": 1.0,\n                    "carFollowModel": "IDM",\n                    "decel": 1.5,\n                    "impatience": 0.5,\n                    "maxSpeed": 30,\n                    "minGap": 2.5,\n                    "sigma": 0.5,\n                    "speedDev": 0.1,\n                    "speedFactor": 1.0,\n                    "tau": 1.0\n                },\n                "speed_mode": 1\n            },\n            "initial_speed": 0,\n            "lane_change_controller": [\n                "SimLaneChangeController",\n                {}\n            ],\n            "lane_change_params": {\n                "controller_params": {\n                    "laneChangeModel": "LC2013",\n                    "lcCooperative": "1.0",\n                    "lcKeepRight": "1.0", ...
#    'run': 'PPO'},
#   'gamma': 0.99,
#   'horizon': 1500,
#   'input': 'sampler',
#   'input_evaluation': None,
#   'kl_coeff': 0.2,
#   'kl_target': 0.01,
#   'lambda': 0.97,
#   'local_evaluator_tf_session_args': {'inter_op_parallelism_threads': 8,
#    'intra_op_parallelism_threads': 8},
#   'log_level': 'INFO',
#   'lr': 0.0005,
#   'lr_schedule': None,
#   'model': {'channel_major': False,
#    'conv_activation': 'relu',
#    'conv_filters': None,
#    'custom_model': None,
#    'custom_options': {},
#    'custom_preprocessor': None,
#    'dim': 84,
#    'fcnet_activation': 'tanh',
#    'fcnet_hiddens': [100, 50, 25],
#    'framestack': True,
#    'free_log_std': False,
#    'grayscale': False,
#    'lstm_cell_size': 256,
#    'lstm_use_prev_action_reward': False,
#    'max_seq_len': 20,
#    'squash_to_range': False,
#    'use_lstm': False,
#    'zero_mean': True},
#   'monitor': False,
#   'multiagent': {'policies_to_train': None,
#    'policy_graphs': {},
#    'policy_mapping_fn': None},
#   'num_cpus_for_driver': 1,
#   'num_cpus_per_worker': 1,
#   'num_envs_per_worker': 1,
#   'num_gpus': 0,
#   'num_gpus_per_worker': 0,
#   'num_sgd_iter': 10,
#   'num_workers': 60,
#   'observation_filter': 'NoFilter',
#   'optimizer': {},
#   'output': None,
#   'output_compress_columns': ['obs', 'new_obs'],
#   'output_max_file_size': 67108864,
#   'preprocessor_pref': 'deepmind',
#   'sample_async': False,
#   'sample_batch_size': 200,
#   'sgd_minibatch_size': 128,
#   'simple_optimizer': False,
#   'straggler_mitigation': False,
#   'synchronize_filters': True,
#   'tf_session_args': {'allow_soft_placement': True,
#    'device_count': {'CPU': 1},
#    'gpu_options': {'allow_growth': True},
#    'inter_op_parallelism_threads': 2,
#    'intra_op_parallelism_threads': 2,
#    'log_device_placement': False},
#   'train_batch_size': 90000,
#   'use_gae': True,
#   'vf_clip_param': 1000000.0,
#   'vf_loss_coeff': 1.0,
#   'vf_share_layers': False},
#  'custom_loggers': None,
#  'local_dir': '/headless/ray_results',
#  'max_failures': 999,
#  'num_samples': 1,
#  'resources_per_trial': None,
#  'restore': '/headless/ray_results/buff_obs/PPO_MultiWaveAttenuationMergePOEnvBufferedObs-v0_[eta1, eta2, eta3]:[1.0, 0.2, 0.3]_t_min:10.0_7_2019-04-28_11-49-51_zkx7fvy/checkpoint_50/checkpoint-50',
#  'run': 'PPO',
#  'stop': {'training_iteration': 55},
#  'sync_function': '',
#  'trial_name_creator': None,
#  'upload_dir': ''}

# %%
trials = run_experiments({
        'resume': exp_tag
    })
# Out:
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 0/62 CPUs, 0/0 GPUs
# Memory usage on this node: 4.9/60.8 GB
#
# Created LogSyncer for /headless/ray_results/resume/PPO_RondomMultiWaveAttenuationMergePOEnvBufferedObs-v0_0_2019-04-28_20-21-59fbbxy7s4 ->
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 61/62 CPUs, 0/0 GPUs
# Memory usage on this node: 13.7/60.8 GB
# Result logdir: /headless/ray_results/resume
# RUNNING trials:
#  - PPO_RondomMultiWaveAttenuationMergePOEnvBufferedObs-v0_0:	RUNNING
#
# Result for PPO_RondomMultiWaveAttenuationMergePOEnvBufferedObs-v0_0:
#   custom_metrics:
#     cost1_max: 422.52381393851556
#     cost1_mean: 335.40206726668885
#     cost1_min: 266.1116126661171
#     cost2_max: -0.05623132780832304
#     cost2_mean: -0.10158752917469
#     cost2_min: -0.37872786335556763
#     outflow_rate_max: 1068.8300648039872
#     outflow_rate_mean: 957.2961641082636
#     outflow_rate_min: 866.969116199853
#     system_level_velocity_max: 15.851506831367999
#     system_level_velocity_mean: 12.453632559070508
#     system_level_velocity_min: 9.837349805671007
#   date: 2019-04-28_20-23-22
#   done: false
#   episode_len_mean: 700.0
#   episode_reward_max: 1326.7873123765012
#   episode_reward_mean: 1257.7897158171204
#   episode_reward_min: 1191.4596539944052
#   episodes_this_iter: 21
#   episodes_total: 2899
#   experiment_id: fac9330d2b9c4ed89736c217e7875e38
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.05000000819563866
#       cur_lr: 0.0005000000237487257
#       entropy: 1.0541415214538574
#       kl: 0.025303218513727188
#       policy_loss: -0.004288277588784695
#       total_loss: 24.034299850463867
#       vf_explained_var: 0.7638465166091919
#       vf_loss: 24.037324905395508
#     grad_time_ms: 24326.436
#     load_time_ms: 65.857
#     num_steps_sampled: 5742575
#     num_steps_trained: 5742575
#     sample_time_ms: 33948.223
#     update_time_ms: 1260.96
#   iterations_since_restore: 1
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 54162
#   policy_reward_mean: {}
#   time_since_restore: 59.8213996887207
#   time_this_iter_s: 59.8213996887207
#   time_total_s: 2131.0115020275116
#   timestamp: 1556483002
#   timesteps_since_restore: 111631
#   timesteps_this_iter: 111631
#   timesteps_total: 5742575
#   training_iteration: 51
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 61/62 CPUs, 0/0 GPUs
# Memory usage on this node: 18.2/60.8 GB
# Result logdir: /headless/ray_results/resume
# RUNNING trials:
#  - PPO_RondomMultiWaveAttenuationMergePOEnvBufferedObs-v0_0:	RUNNING [pid=54162], 2131 s, 51 iter, 5742575 ts, 1.26e+03 rew
#
# Result for PPO_RondomMultiWaveAttenuationMergePOEnvBufferedObs-v0_0:
#   custom_metrics:
#     cost1_max: 422.52381393851556
#     cost1_mean: 315.4255974509117
#     cost1_min: 248.971637731363
#     cost2_max: -0.05623132780832304
#     cost2_mean: -0.09517323932786338
#     cost2_min: -0.37872786335556763
#     outflow_rate_max: 1070.0259331181012
#     outflow_rate_mean: 931.6097878344569
#     outflow_rate_min: 822.2551379856293
#     system_level_velocity_max: 15.851506831367999
#     system_level_velocity_mean: 11.688007091092372
#     system_level_velocity_min: 9.249433050801994
#   date: 2019-04-28_20-24-00
#   done: false
#   episode_len_mean: 700.0
#   episode_reward_max: 1334.987452013555
#   episode_reward_mean: 1245.1177978892229
#   episode_reward_min: 1136.3154317598899
#   episodes_this_iter: 76
#   episodes_total: 2975
#   experiment_id: fac9330d2b9c4ed89736c217e7875e38
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.30000001192092896
#       cur_lr: 0.0005000000237487257
#       entropy: 1.067395567893982
#       kl: 0.005924363154917955
#       policy_loss: -0.002009894698858261
#       total_loss: 62.10307693481445
#       vf_explained_var: 0.5331664085388184
#       vf_loss: 62.103302001953125
#     grad_time_ms: 22624.171
#     load_time_ms: 39.976
#     num_steps_sampled: 5855299
#     num_steps_trained: 5855299
#     sample_time_ms: 24964.434
#     update_time_ms: 636.022
#   iterations_since_restore: 2
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 54162
#   policy_reward_mean: {}
#   time_since_restore: 96.93514609336853
#   time_this_iter_s: 37.11374640464783
#   time_total_s: 2168.1252484321594
#   timestamp: 1556483040
#   timesteps_since_restore: 224355
#   timesteps_this_iter: 112724
#   timesteps_total: 5855299
#   training_iteration: 52
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 61/62 CPUs, 0/0 GPUs
# Memory usage on this node: 18.3/60.8 GB
# Result logdir: /headless/ray_results/resume
# RUNNING trials:
#  - PPO_RondomMultiWaveAttenuationMergePOEnvBufferedObs-v0_0:	RUNNING [pid=54162], 2168 s, 52 iter, 5855299 ts, 1.25e+03 rew
#
# Result for PPO_RondomMultiWaveAttenuationMergePOEnvBufferedObs-v0_0:
#   custom_metrics:
#     cost1_max: 414.32777948284513
#     cost1_mean: 301.4189239125206
#     cost1_min: 218.9329799511483
#     cost2_max: -0.056218692731902685
#     cost2_mean: -0.09454880409840845
#     cost2_min: -0.6373768518125549
#     outflow_rate_max: 1070.0259331181012
#     outflow_rate_mean: 912.8643727294094
#     outflow_rate_min: 804.0147079742263
#     system_level_velocity_max: 15.83655826325681
#     system_level_velocity_mean: 11.239266035293058
#     system_level_velocity_min: 8.923940623577447
#   date: 2019-04-28_20-24-36
#   done: false
#   episode_len_mean: 696.63
#   episode_reward_max: 1326.8148470156689
#   episode_reward_mean: 1226.5400198491639
#   episode_reward_min: 654.9817305165486
#   episodes_this_iter: 55
#   episodes_total: 3030
#   experiment_id: fac9330d2b9c4ed89736c217e7875e38
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.29999998211860657
#       cur_lr: 0.0005000000237487257
#       entropy: 1.0781208276748657
#       kl: 0.0054052285850048065
#       policy_loss: -0.0016867168014869094
#       total_loss: 48.02827072143555
#       vf_explained_var: 0.552092432975769
#       vf_loss: 48.02833938598633
#     grad_time_ms: 22196.333
#     load_time_ms: 31.617
#     num_steps_sampled: 5965994
#     num_steps_trained: 5965994
#     sample_time_ms: 21600.204
#     update_time_ms: 428.455
#   iterations_since_restore: 3
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 54162
#   policy_reward_mean: {}
#   time_since_restore: 133.3622326850891
#   time_this_iter_s: 36.42708659172058
#   time_total_s: 2204.55233502388
#   timestamp: 1556483076
#   timesteps_since_restore: 335050
#   timesteps_this_iter: 110695
#   timesteps_total: 5965994
#   training_iteration: 53
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 61/62 CPUs, 0/0 GPUs
# Memory usage on this node: 18.3/60.8 GB
# Result logdir: /headless/ray_results/resume
# RUNNING trials:
#  - PPO_RondomMultiWaveAttenuationMergePOEnvBufferedObs-v0_0:	RUNNING [pid=54162], 2204 s, 53 iter, 5965994 ts, 1.23e+03 rew
#
# Result for PPO_RondomMultiWaveAttenuationMergePOEnvBufferedObs-v0_0:
#   custom_metrics:
#     cost1_max: 418.84129403232214
#     cost1_mean: 300.3276661454649
#     cost1_min: 218.9329799511483
#     cost2_max: -0.0561963147132335
#     cost2_mean: -0.10367101762370344
#     cost2_min: -0.6373768518125549
#     outflow_rate_max: 1066.3062585392597
#     outflow_rate_mean: 907.6808156445935
#     outflow_rate_min: 802.8126822824256
#     system_level_velocity_max: 15.83655826325681
#     system_level_velocity_mean: 11.211772692975291
#     system_level_velocity_min: 8.635244451129742
#   date: 2019-04-28_20-25-13
#   done: false
#   episode_len_mean: 696.63
#   episode_reward_max: 1343.9755417128752
#   episode_reward_mean: 1220.4529833812037
#   episode_reward_min: 654.9817305165486
#   episodes_this_iter: 63
#   episodes_total: 3093
#   experiment_id: fac9330d2b9c4ed89736c217e7875e38
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.29999998211860657
#       cur_lr: 0.0005000000237487257
#       entropy: 1.08139967918396
#       kl: 0.005689824931323528
#       policy_loss: -0.002202307339757681
#       total_loss: 55.161354064941406
#       vf_explained_var: 0.5594301819801331
#       vf_loss: 55.16184997558594
#     grad_time_ms: 22019.909
#     load_time_ms: 27.816
#     num_steps_sampled: 6077880
#     num_steps_trained: 6077880
#     sample_time_ms: 20073.122
#     update_time_ms: 324.89
#   iterations_since_restore: 4
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 54162
#   policy_reward_mean: {}
#   time_since_restore: 170.54851913452148
#   time_this_iter_s: 37.18628644943237
#   time_total_s: 2241.7386214733124
#   timestamp: 1556483113
#   timesteps_since_restore: 446936
#   timesteps_this_iter: 111886
#   timesteps_total: 6077880
#   training_iteration: 54
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 61/62 CPUs, 0/0 GPUs
# Memory usage on this node: 18.4/60.8 GB
# Result logdir: /headless/ray_results/resume
# RUNNING trials:
#  - PPO_RondomMultiWaveAttenuationMergePOEnvBufferedObs-v0_0:	RUNNING [pid=54162], 2241 s, 54 iter, 6077880 ts, 1.22e+03 rew
#
# Result for PPO_RondomMultiWaveAttenuationMergePOEnvBufferedObs-v0_0:
#   custom_metrics:
#     cost1_max: 420.27899713393066
#     cost1_mean: 304.8641079858787
#     cost1_min: 231.0697119961885
#     cost2_max: -0.0561963147132335
#     cost2_mean: -0.10067309673319903
#     cost2_min: -0.41198749972064197
#     outflow_rate_max: 1066.4535322036138
#     outflow_rate_mean: 909.9508155068143
#     outflow_rate_min: 802.8126822824256
#     system_level_velocity_max: 15.72486523642408
#     system_level_velocity_mean: 11.295167940033933
#     system_level_velocity_min: 8.635244451129742
#   date: 2019-04-28_20-25-51
#   done: true
#   episode_len_mean: 700.0
#   episode_reward_max: 1346.0449733335574
#   episode_reward_mean: 1223.3542891464565
#   episode_reward_min: 1127.8765189776502
#   episodes_this_iter: 56
#   episodes_total: 3149
#   experiment_id: fac9330d2b9c4ed89736c217e7875e38
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.2999999523162842
#       cur_lr: 0.0005000000237487257
#       entropy: 1.0763168334960938
#       kl: 0.005458921194076538
#       policy_loss: -0.0020348087418824434
#       total_loss: 48.4703483581543
#       vf_explained_var: 0.5620078444480896
#       vf_loss: 48.47074508666992
#     grad_time_ms: 22052.46
#     load_time_ms: 26.985
#     num_steps_sampled: 6188397
#     num_steps_trained: 6188397
#     sample_time_ms: 19082.934
#     update_time_ms: 261.945
#   iterations_since_restore: 5
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 54162
#   policy_reward_mean: {}
#   time_since_restore: 208.11226224899292
#   time_this_iter_s: 37.563743114471436
#   time_total_s: 2279.302364587784
#   timestamp: 1556483151
#   timesteps_since_restore: 557453
#   timesteps_this_iter: 110517
#   timesteps_total: 6188397
#   training_iteration: 55
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 0/62 CPUs, 0/0 GPUs
# Memory usage on this node: 18.2/60.8 GB
# Result logdir: /headless/ray_results/resume
# TERMINATED trials:
#  - PPO_RondomMultiWaveAttenuationMergePOEnvBufferedObs-v0_0:	TERMINATED [pid=54162], 2279 s, 55 iter, 6188397 ts, 1.22e+03 rew
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 0/62 CPUs, 0/0 GPUs
# Memory usage on this node: 18.2/60.8 GB
# Result logdir: /headless/ray_results/resume
# TERMINATED trials:
#  - PPO_RondomMultiWaveAttenuationMergePOEnvBufferedObs-v0_0:	TERMINATED [pid=54162], 2279 s, 55 iter, 6188397 ts, 1.22e+03 rew

# %%
config
# Out:
# {'batch_mode': 'truncate_episodes',
#  'callbacks': {'on_episode_end': <ray.tune.suggest.variant_generator.function at 0x7fb3838e9780>,
#   'on_episode_start': <ray.tune.suggest.variant_generator.function at 0x7fb3838e9278>,
#   'on_episode_step': <ray.tune.suggest.variant_generator.function at 0x7fb3838e9710>,
#   'on_sample_end': None,
#   'on_train_result': None},
#  'clip_actions': False,
#  'clip_param': 0.3,
#  'clip_rewards': None,
#  'collect_metrics_timeout': 180,
#  'compress_observations': False,
#  'custom_resources_per_worker': {},
#  'entropy_coeff': 0.0,
#  'env': 'MultiWaveAttenuationMergePOEnvBufferedObs-v0_[eta1, eta2, eta3]:[1.0, 0.2, 0.3]_t_min:10.0',
#  'env_config': {'flow_params': '{\n    "env": {\n        "additional_params": {\n            "FLOW_RATE": 2000,\n            "eta1": 1.0,\n            "eta2": 0.3,\n            "eta3": 0.3,\n            "max_accel": 3,\n            "max_decel": 3,\n            "reward_scale": 1.0,\n            "t_min": 7.0,\n            "target_velocity": 25\n        },\n        "evaluate": false,\n        "horizon": 1500,\n        "sims_per_step": 2,\n        "warmup_steps": 100\n    },\n    "env_name": "MultiWaveAttenuationMergePOEnvBufferedObs",\n    "exp_tag": "multi_merge",\n    "initial": {\n        "additional_params": {},\n        "bunching": 0,\n        "edges_distribution": "all",\n        "lanes_distribution": Infinity,\n        "min_gap": 0,\n        "perturbation": 0.0,\n        "shuffle": false,\n        "spacing": "uniform",\n        "x0": 0\n    },\n    "net": {\n        "additional_params": {\n            "highway_lanes": 1,\n            "merge_lanes": 1,\n            "merge_length": 100,\n            "post_merge_length": 100,\n            "pre_merge_length": 600,\n            "speed_limit": 30\n        },\n        "inflows": {\n            "_InFlows__flows": [\n                {\n                    "begin": 1,\n                    "departLane": "free",\n                    "departSpeed": 10,\n                    "edge": "inflow_highway",\n                    "end": 2000000.0,\n                    "name": "flow_0",\n                    "vehsPerHour": 1800.0,\n                    "vtype": "human"\n                },\n                {\n                    "begin": 1,\n                    "departLane": "free",\n                    "departSpeed": 10,\n                    "edge": "inflow_highway",\n                    "end": 2000000.0,\n                    "name": "flow_1",\n                    "vehsPerHour": 200.0,\n                    "vtype": "rl"\n                },\n                {\n                    "begin": 1,\n                    "departLane": "free",\n                    "departSpeed": 7.5,\n                    "edge": "inflow_merge",\n                    "end": 2000000.0,\n                    "name": "flow_2",\n                    "vehsPerHour": 100,\n                    "vtype": "human"\n                }\n            ],\n            "num_flows": 3\n        },\n        "netfile": null,\n        "no_internal_links": false,\n        "osm_path": null\n    },\n    "scenario": "MergeScenario",\n    "sim": {\n        "emission_path": null,\n        "lateral_resolution": null,\n        "no_step_log": true,\n        "num_clients": 1,\n        "overtake_right": false,\n        "port": null,\n        "print_warnings": true,\n        "pxpm": 2,\n        "render": false,\n        "restart_instance": true,\n        "save_render": false,\n        "seed": null,\n        "show_radius": false,\n        "sight_radius": 25,\n        "sim_step": 0.2,\n        "teleport_time": -1\n    },\n    "simulator": "traci",\n    "veh": [\n        {\n            "acceleration_controller": [\n                "SimCarFollowingController",\n                {}\n            ],\n            "car_following_params": {\n                "controller_params": {\n                    "accel": 1.0,\n                    "carFollowModel": "IDM",\n                    "decel": 1.5,\n                    "impatience": 0.5,\n                    "maxSpeed": 30,\n                    "minGap": 2.5,\n                    "sigma": 0.5,\n                    "speedDev": 0.1,\n                    "speedFactor": 1.0,\n                    "tau": 1.0\n                },\n                "speed_mode": 1\n            },\n            "initial_speed": 0,\n            "lane_change_controller": [\n                "SimLaneChangeController",\n                {}\n            ],\n            "lane_change_params": {\n                "controller_params": {\n                    "laneChangeModel": "LC2013",\n                    "lcCooperative": "1.0",\n                    "lcKeepRight": "1.0",\ ...
#   'run': 'PPO'},
#  'gamma': 0.99,
#  'horizon': 1500,
#  'input': 'sampler',
#  'input_evaluation': None,
#  'kl_coeff': 0.2,
#  'kl_target': 0.01,
#  'lambda': 0.97,
#  'local_evaluator_tf_session_args': {'inter_op_parallelism_threads': 8,
#   'intra_op_parallelism_threads': 8},
#  'log_level': 'INFO',
#  'lr': 0.0005,
#  'lr_schedule': None,
#  'model': {'channel_major': False,
#   'conv_activation': 'relu',
#   'conv_filters': None,
#   'custom_model': None,
#   'custom_options': {},
#   'custom_preprocessor': None,
#   'dim': 84,
#   'fcnet_activation': 'tanh',
#   'fcnet_hiddens': [100, 50, 25],
#   'framestack': True,
#   'free_log_std': False,
#   'grayscale': False,
#   'lstm_cell_size': 256,
#   'lstm_use_prev_action_reward': False,
#   'max_seq_len': 20,
#   'squash_to_range': False,
#   'use_lstm': False,
#   'zero_mean': True},
#  'monitor': False,
#  'multiagent': {'policies_to_train': None,
#   'policy_graphs': {},
#   'policy_mapping_fn': None},
#  'num_cpus_for_driver': 1,
#  'num_cpus_per_worker': 1,
#  'num_envs_per_worker': 1,
#  'num_gpus': 0,
#  'num_gpus_per_worker': 0,
#  'num_sgd_iter': 10,
#  'num_workers': 60,
#  'observation_filter': 'NoFilter',
#  'optimizer': {},
#  'output': None,
#  'output_compress_columns': ['obs', 'new_obs'],
#  'output_max_file_size': 67108864,
#  'preprocessor_pref': 'deepmind',
#  'sample_async': False,
#  'sample_batch_size': 200,
#  'sgd_minibatch_size': 128,
#  'simple_optimizer': False,
#  'straggler_mitigation': False,
#  'synchronize_filters': True,
#  'tf_session_args': {'allow_soft_placement': True,
#   'device_count': {'CPU': 1},
#   'gpu_options': {'allow_growth': True},
#   'inter_op_parallelism_threads': 2,
#   'intra_op_parallelism_threads': 2,
#   'log_device_placement': False},
#  'train_batch_size': 90000,
#  'use_gae': True,
#  'vf_clip_param': 1000000.0,
#  'vf_loss_coeff': 1.0,
#  'vf_share_layers': False}
