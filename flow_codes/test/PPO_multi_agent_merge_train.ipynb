# %%
from common.evaluate import make_vis_env, test_env

from flow.multiagent_envs import MultiWaveAttenuationMergePOEnv
from flow.scenarios import MergeScenario
from flow.utils.registry import make_create_env
from flow.utils.rllib import FlowParamsEncoder
from ray.tune import run_experiments

import gym, ray
from ray.rllib.agents.ppo import PPOAgent, DEFAULT_CONFIG
from ray.tune.registry import register_env
from ray.tune.logger import pretty_print

benchmark_name = 'multi_merge'

# %%
alg_run = "PPO"
num_rollouts = 60
num_cpus = 63
gae_lambda = 0.97
step_size = 5e-4

# %%
ray.init(num_cpus=num_cpus, include_webui=False, ignore_reinit_error=True)
# Out:
# Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-04-18_22-06-04_113/logs.
# Waiting for redis server at 127.0.0.1:22417 to respond...
# Waiting for redis server at 127.0.0.1:20317 to respond...
# Warning: Capping object memory store to 20.0GB. To increase this further, specify `object_store_memory` when calling ray.init() or ray start.
# Starting the Plasma object store with 20.0 GB memory using /dev/shm.
# {'node_ip_address': '10.138.0.2',
#  'object_store_addresses': ['/tmp/ray/session_2019-04-18_22-06-04_113/sockets/plasma_store'],
#  'raylet_socket_names': ['/tmp/ray/session_2019-04-18_22-06-04_113/sockets/raylet'],
#  'redis_address': '10.138.0.2:22417',
#  'webui_url': ''}

# %%
benchmark = __import__(
    "flow.benchmarks.%s" % benchmark_name, fromlist=["flow_params"])
flow_params = benchmark.flow_params
horizon = flow_params['env'].horizon

def make_env(create_env):
    def _thunk():
        env = create_env()
        return env
    return _thunk

create_env, env_name = make_create_env(params=flow_params, version=0)

# %%
config = DEFAULT_CONFIG.copy()

# %%
config["num_workers"] = min(num_cpus, num_rollouts) - 1
config["train_batch_size"] = horizon * num_rollouts
config["use_gae"] = True
config["horizon"] = horizon
config["lambda"] = gae_lambda
config["lr"] = step_size
config["vf_clip_param"] = 1e6
config["num_sgd_iter"] = 10
config['clip_actions'] = False  # FIXME(ev) temporary ray bug
config["model"]["fcnet_hiddens"] = [100, 50, 25]
config["observation_filter"] = "NoFilter"

# save the flow params for replay
flow_json = json.dumps(
    flow_params, cls=FlowParamsEncoder, sort_keys=True, indent=4)
config['env_config']['flow_params'] = flow_json
config['env_config']['run'] = alg_run

# %%
# Register as rllib env
register_env(env_name, create_env)

# %%
exp_tag = {
    "run": alg_run,
    "env": env_name,
    "config": {
        **config
    },
    "checkpoint_freq": 25,
    "max_failures": 999,
    "stop": {
        "training_iteration": 500
    },
    "num_samples": 1,
}

# %%
trials = run_experiments({
        flow_params["exp_tag"]: exp_tag
    })
# Out:
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 0/63 CPUs, 0/0 GPUs
# Memory usage on this node: 3.0/94.8 GB
#
# Created LogSyncer for /headless/ray_results/multi_merge/PPO_MultiWaveAttenuationMergePOEnv-v0_0_2019-04-18_22-06-061w6z291m ->
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 3.3/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-07-17
#   done: false
#   episode_len_mean: .nan
#   episode_reward_max: .nan
#   episode_reward_mean: .nan
#   episode_reward_min: .nan
#   episodes_this_iter: 0
#   episodes_total: 0
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.20000001788139343
#       cur_lr: 0.0005000000237487257
#       entropy: 1.4259556531906128
#       kl: 0.0009673548629507422
#       policy_loss: -0.000401158700697124
#       total_loss: 1.1667954921722412
#       vf_explained_var: 0.5617018342018127
#       vf_loss: 1.1670031547546387
#     grad_time_ms: 14579.219
#     load_time_ms: 52.853
#     num_steps_sampled: 73446
#     num_steps_trained: 73446
#     sample_time_ms: 26177.824
#     update_time_ms: 1144.522
#   iterations_since_restore: 1
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 42.12158155441284
#   time_this_iter_s: 42.12158155441284
#   time_total_s: 42.12158155441284
#   timestamp: 1555625237
#   timesteps_since_restore: 73446
#   timesteps_this_iter: 73446
#   timesteps_total: 73446
#   training_iteration: 1
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.0/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 42 s, 1 iter, 73446 ts, nan rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-07-42
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 281.82053060445435
#   episode_reward_mean: 253.58697085766823
#   episode_reward_min: 230.37675360911427
#   episodes_this_iter: 17
#   episodes_total: 17
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.10000000894069672
#       cur_lr: 0.0005000000237487257
#       entropy: 1.4158329963684082
#       kl: 0.0077108051627874374
#       policy_loss: -0.003883913392201066
#       total_loss: 0.2862303555011749
#       vf_explained_var: 0.6897832155227661
#       vf_loss: 0.2893431782722473
#     grad_time_ms: 14524.129
#     load_time_ms: 29.516
#     num_steps_sampled: 150571
#     num_steps_trained: 150571
#     sample_time_ms: 18176.717
#     update_time_ms: 576.844
#   iterations_since_restore: 2
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 66.88648700714111
#   time_this_iter_s: 24.76490545272827
#   time_total_s: 66.88648700714111
#   timestamp: 1555625262
#   timesteps_since_restore: 150571
#   timesteps_this_iter: 77125
#   timesteps_total: 150571
#   training_iteration: 2
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.0/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 66 s, 2 iter, 150571 ts, 254 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-08-05
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 346.1693524499015
#   episode_reward_mean: 273.1699265055127
#   episode_reward_min: 229.04169320792337
#   episodes_this_iter: 32
#   episodes_total: 49
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.10000000894069672
#       cur_lr: 0.0005000000237487257
#       entropy: 1.401599645614624
#       kl: 0.0070348684675991535
#       policy_loss: -0.0036649645771831274
#       total_loss: 1.1519864797592163
#       vf_explained_var: 0.6186231374740601
#       vf_loss: 1.1549478769302368
#     grad_time_ms: 14196.248
#     load_time_ms: 21.768
#     num_steps_sampled: 224462
#     num_steps_trained: 224462
#     sample_time_ms: 15546.308
#     update_time_ms: 387.884
#   iterations_since_restore: 3
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 90.80549240112305
#   time_this_iter_s: 23.919005393981934
#   time_total_s: 90.80549240112305
#   timestamp: 1555625285
#   timesteps_since_restore: 224462
#   timesteps_this_iter: 73891
#   timesteps_total: 224462
#   training_iteration: 3
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.0/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 90 s, 3 iter, 224462 ts, 273 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-08-28
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 681.3658648709823
#   episode_reward_mean: 321.71506752814247
#   episode_reward_min: 229.04169320792337
#   episodes_this_iter: 14
#   episodes_total: 63
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.10000001639127731
#       cur_lr: 0.0005000000237487257
#       entropy: 1.3935638666152954
#       kl: 0.00662206532433629
#       policy_loss: -0.0028889141976833344
#       total_loss: 2.5087482929229736
#       vf_explained_var: 0.4566577970981598
#       vf_loss: 2.510974884033203
#     grad_time_ms: 13963.145
#     load_time_ms: 17.604
#     num_steps_sampled: 294349
#     num_steps_trained: 294349
#     sample_time_ms: 14046.672
#     update_time_ms: 292.929
#   iterations_since_restore: 4
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 113.71080350875854
#   time_this_iter_s: 22.905311107635498
#   time_total_s: 113.71080350875854
#   timestamp: 1555625308
#   timesteps_since_restore: 294349
#   timesteps_this_iter: 69887
#   timesteps_total: 294349
#   training_iteration: 4
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.0/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 113 s, 4 iter, 294349 ts, 322 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-08-50
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 718.2906724560113
#   episode_reward_mean: 382.386906015662
#   episode_reward_min: 229.04169320792337
#   episodes_this_iter: 21
#   episodes_total: 84
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.10000001639127731
#       cur_lr: 0.0005000000237487257
#       entropy: 1.3758779764175415
#       kl: 0.004739989992231131
#       policy_loss: -0.0012855217792093754
#       total_loss: 4.1757097244262695
#       vf_explained_var: 0.4242079555988312
#       vf_loss: 4.176520347595215
#     grad_time_ms: 13514.266
#     load_time_ms: 15.282
#     num_steps_sampled: 362923
#     num_steps_trained: 362923
#     sample_time_ms: 13151.934
#     update_time_ms: 236.417
#   iterations_since_restore: 5
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 135.10419297218323
#   time_this_iter_s: 21.393389463424683
#   time_total_s: 135.10419297218323
#   timestamp: 1555625330
#   timesteps_since_restore: 362923
#   timesteps_this_iter: 68574
#   timesteps_total: 362923
#   training_iteration: 5
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.1/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 135 s, 5 iter, 362923 ts, 382 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-09-11
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 739.3057172871429
#   episode_reward_mean: 437.722180666285
#   episode_reward_min: 229.04169320792337
#   episodes_this_iter: 21
#   episodes_total: 105
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.05000000447034836
#       cur_lr: 0.0005000000237487257
#       entropy: 1.3542811870574951
#       kl: 0.00661829300224781
#       policy_loss: -0.002071317518129945
#       total_loss: 4.905956268310547
#       vf_explained_var: 0.36273157596588135
#       vf_loss: 4.907696723937988
#     grad_time_ms: 13238.315
#     load_time_ms: 13.533
#     num_steps_sampled: 429678
#     num_steps_trained: 429678
#     sample_time_ms: 12532.781
#     update_time_ms: 198.458
#   iterations_since_restore: 6
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 156.49344444274902
#   time_this_iter_s: 21.389251470565796
#   time_total_s: 156.49344444274902
#   timestamp: 1555625351
#   timesteps_since_restore: 429678
#   timesteps_this_iter: 66755
#   timesteps_total: 429678
#   training_iteration: 6
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.1/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 156 s, 6 iter, 429678 ts, 438 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-09-34
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 804.927290589831
#   episode_reward_mean: 522.8962128665526
#   episode_reward_min: 229.04169320792337
#   episodes_this_iter: 21
#   episodes_total: 126
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.050000011920928955
#       cur_lr: 0.0005000000237487257
#       entropy: 1.3389524221420288
#       kl: 0.00568394735455513
#       policy_loss: -0.0016918210312724113
#       total_loss: 4.6704840660095215
#       vf_explained_var: 0.2818896472454071
#       vf_loss: 4.671890735626221
#     grad_time_ms: 13184.512
#     load_time_ms: 12.3
#     num_steps_sampled: 496714
#     num_steps_trained: 496714
#     sample_time_ms: 12102.135
#     update_time_ms: 171.484
#   iterations_since_restore: 7
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 178.97278428077698
#   time_this_iter_s: 22.479339838027954
#   time_total_s: 178.97278428077698
#   timestamp: 1555625374
#   timesteps_since_restore: 496714
#   timesteps_this_iter: 67036
#   timesteps_total: 496714
#   training_iteration: 7
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.1/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 178 s, 7 iter, 496714 ts, 523 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-09-55
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 804.927290589831
#   episode_reward_mean: 603.3991643533535
#   episode_reward_min: 241.95021054979355
#   episodes_this_iter: 20
#   episodes_total: 146
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.05000000447034836
#       cur_lr: 0.0005000000237487257
#       entropy: 1.3429161310195923
#       kl: 0.0062518795020878315
#       policy_loss: -0.001770914881490171
#       total_loss: 5.278972148895264
#       vf_explained_var: 0.28840288519859314
#       vf_loss: 5.280429840087891
#     grad_time_ms: 12976.861
#     load_time_ms: 11.351
#     num_steps_sampled: 564913
#     num_steps_trained: 564913
#     sample_time_ms: 11739.156
#     update_time_ms: 151.305
#   iterations_since_restore: 8
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 199.789626121521
#   time_this_iter_s: 20.81684184074402
#   time_total_s: 199.789626121521
#   timestamp: 1555625395
#   timesteps_since_restore: 564913
#   timesteps_this_iter: 68199
#   timesteps_total: 564913
#   training_iteration: 8
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.1/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 199 s, 8 iter, 564913 ts, 603 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-10-17
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 829.2028958650477
#   episode_reward_mean: 663.5555899624825
#   episode_reward_min: 405.42611592414846
#   episodes_this_iter: 29
#   episodes_total: 175
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.05000000819563866
#       cur_lr: 0.0005000000237487257
#       entropy: 1.3412878513336182
#       kl: 0.0031223336700350046
#       policy_loss: -0.00023664938635192811
#       total_loss: 7.043185234069824
#       vf_explained_var: 0.239460289478302
#       vf_loss: 7.043265342712402
#     grad_time_ms: 12942.284
#     load_time_ms: 10.822
#     num_steps_sampled: 632803
#     num_steps_trained: 632803
#     sample_time_ms: 11520.1
#     update_time_ms: 135.438
#   iterations_since_restore: 9
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 222.32942628860474
#   time_this_iter_s: 22.53980016708374
#   time_total_s: 222.32942628860474
#   timestamp: 1555625417
#   timesteps_since_restore: 632803
#   timesteps_this_iter: 67890
#   timesteps_total: 632803
#   training_iteration: 9
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.1/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 222 s, 9 iter, 632803 ts, 664 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-10-39
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 867.2541512893827
#   episode_reward_mean: 693.4228874029482
#   episode_reward_min: 571.9824459303691
#   episodes_this_iter: 22
#   episodes_total: 197
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.02500000409781933
#       cur_lr: 0.0005000000237487257
#       entropy: 1.3383238315582275
#       kl: 0.004797221161425114
#       policy_loss: -0.00043641365482471883
#       total_loss: 6.087734222412109
#       vf_explained_var: 0.2535492479801178
#       vf_loss: 6.088050842285156
#     grad_time_ms: 12806.219
#     load_time_ms: 10.414
#     num_steps_sampled: 699951
#     num_steps_trained: 699951
#     sample_time_ms: 11381.471
#     update_time_ms: 122.915
#   iterations_since_restore: 10
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 244.14739513397217
#   time_this_iter_s: 21.81796884536743
#   time_total_s: 244.14739513397217
#   timestamp: 1555625439
#   timesteps_since_restore: 699951
#   timesteps_this_iter: 67148
#   timesteps_total: 699951
#   training_iteration: 10
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.1/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 244 s, 10 iter, 699951 ts, 693 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-11-00
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 867.2541512893827
#   episode_reward_mean: 708.4381570043324
#   episode_reward_min: 622.8057770041098
#   episodes_this_iter: 27
#   episodes_total: 224
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.012500002048909664
#       cur_lr: 0.0005000000237487257
#       entropy: 1.3443048000335693
#       kl: 0.0038769750390201807
#       policy_loss: -0.0007263637380674481
#       total_loss: 7.317861557006836
#       vf_explained_var: 0.2296217381954193
#       vf_loss: 7.318539619445801
#     grad_time_ms: 12496.763
#     load_time_ms: 5.614
#     num_steps_sampled: 765972
#     num_steps_trained: 765972
#     sample_time_ms: 9726.407
#     update_time_ms: 9.487
#   iterations_since_restore: 11
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 265.3519322872162
#   time_this_iter_s: 21.20453715324402
#   time_total_s: 265.3519322872162
#   timestamp: 1555625460
#   timesteps_since_restore: 765972
#   timesteps_this_iter: 66021
#   timesteps_total: 765972
#   training_iteration: 11
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.1/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 265 s, 11 iter, 765972 ts, 708 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-11-22
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 867.2541512893827
#   episode_reward_mean: 711.8332917252072
#   episode_reward_min: 627.6192255625829
#   episodes_this_iter: 18
#   episodes_total: 242
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.006250001024454832
#       cur_lr: 0.0005000000237487257
#       entropy: 1.3406423330307007
#       kl: 0.006785277742892504
#       policy_loss: -0.0009150953846983612
#       total_loss: 6.053147315979004
#       vf_explained_var: 0.28933441638946533
#       vf_loss: 6.054020404815674
#     grad_time_ms: 12277.52
#     load_time_ms: 5.452
#     num_steps_sampled: 833051
#     num_steps_trained: 833051
#     sample_time_ms: 9667.691
#     update_time_ms: 9.589
#   iterations_since_restore: 12
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 287.3118517398834
#   time_this_iter_s: 21.959919452667236
#   time_total_s: 287.3118517398834
#   timestamp: 1555625482
#   timesteps_since_restore: 833051
#   timesteps_this_iter: 67079
#   timesteps_total: 833051
#   training_iteration: 12
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.1/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 287 s, 12 iter, 833051 ts, 712 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-11-44
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 867.2541512893827
#   episode_reward_mean: 712.5467401418788
#   episode_reward_min: 627.6192255625829
#   episodes_this_iter: 15
#   episodes_total: 257
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.006250000558793545
#       cur_lr: 0.0005000000237487257
#       entropy: 1.3412318229675293
#       kl: 0.003936938010156155
#       policy_loss: -0.000680316414218396
#       total_loss: 5.847048759460449
#       vf_explained_var: 0.29600462317466736
#       vf_loss: 5.8477044105529785
#     grad_time_ms: 12136.675
#     load_time_ms: 5.501
#     num_steps_sampled: 900487
#     num_steps_trained: 900487
#     sample_time_ms: 9556.207
#     update_time_ms: 9.407
#   iterations_since_restore: 13
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 308.7157356739044
#   time_this_iter_s: 21.403883934020996
#   time_total_s: 308.7157356739044
#   timestamp: 1555625504
#   timesteps_since_restore: 900487
#   timesteps_this_iter: 67436
#   timesteps_total: 900487
#   training_iteration: 13
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.2/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 308 s, 13 iter, 900487 ts, 713 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-12-04
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 867.2541512893827
#   episode_reward_mean: 710.9411993866535
#   episode_reward_min: 627.6192255625829
#   episodes_this_iter: 23
#   episodes_total: 280
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.003125000512227416
#       cur_lr: 0.0005000000237487257
#       entropy: 1.3365957736968994
#       kl: 0.004646865651011467
#       policy_loss: -0.0005948443431407213
#       total_loss: 7.309628963470459
#       vf_explained_var: 0.2511301338672638
#       vf_loss: 7.310209274291992
#     grad_time_ms: 11906.284
#     load_time_ms: 5.298
#     num_steps_sampled: 966033
#     num_steps_trained: 966033
#     sample_time_ms: 9532.132
#     update_time_ms: 9.498
#   iterations_since_restore: 14
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 329.0678653717041
#   time_this_iter_s: 20.352129697799683
#   time_total_s: 329.0678653717041
#   timestamp: 1555625524
#   timesteps_since_restore: 966033
#   timesteps_this_iter: 65546
#   timesteps_total: 966033
#   training_iteration: 14
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.2/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 329 s, 14 iter, 966033 ts, 711 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-12-24
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 838.6269039393886
#   episode_reward_mean: 706.0023048501233
#   episode_reward_min: 627.6192255625829
#   episodes_this_iter: 26
#   episodes_total: 306
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.001562500256113708
#       cur_lr: 0.0005000000237487257
#       entropy: 1.3423516750335693
#       kl: 0.0038883681409060955
#       policy_loss: -0.0005283473874442279
#       total_loss: 8.335515975952148
#       vf_explained_var: 0.23271065950393677
#       vf_loss: 8.336038589477539
#     grad_time_ms: 11855.74
#     load_time_ms: 5.199
#     num_steps_sampled: 1031894
#     num_steps_trained: 1031894
#     sample_time_ms: 9489.841
#     update_time_ms: 9.354
#   iterations_since_restore: 15
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 349.5323853492737
#   time_this_iter_s: 20.46451997756958
#   time_total_s: 349.5323853492737
#   timestamp: 1555625544
#   timesteps_since_restore: 1031894
#   timesteps_this_iter: 65861
#   timesteps_total: 1031894
#   training_iteration: 15
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.2/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 349 s, 15 iter, 1031894 ts, 706 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-12-46
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 838.6269039393886
#   episode_reward_mean: 707.7145885862387
#   episode_reward_min: 627.6192255625829
#   episodes_this_iter: 15
#   episodes_total: 321
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.0007812500698491931
#       cur_lr: 0.0005000000237487257
#       entropy: 1.322128415107727
#       kl: 0.006687772925943136
#       policy_loss: -0.000904607237316668
#       total_loss: 6.276336669921875
#       vf_explained_var: 0.3180244565010071
#       vf_loss: 6.277235984802246
#     grad_time_ms: 11847.647
#     load_time_ms: 5.257
#     num_steps_sampled: 1099873
#     num_steps_trained: 1099873
#     sample_time_ms: 9493.151
#     update_time_ms: 9.445
#   iterations_since_restore: 16
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 370.87363839149475
#   time_this_iter_s: 21.34125304222107
#   time_total_s: 370.87363839149475
#   timestamp: 1555625566
#   timesteps_since_restore: 1099873
#   timesteps_this_iter: 67979
#   timesteps_total: 1099873
#   training_iteration: 16
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.2/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 370 s, 16 iter, 1099873 ts, 708 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-13-07
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 859.8649373384592
#   episode_reward_mean: 707.882767128422
#   episode_reward_min: 631.9345002521995
#   episodes_this_iter: 21
#   episodes_total: 342
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.000781250128056854
#       cur_lr: 0.0005000000237487257
#       entropy: 1.314633846282959
#       kl: 0.005821126978844404
#       policy_loss: -0.0007752349483780563
#       total_loss: 7.897635459899902
#       vf_explained_var: 0.27619868516921997
#       vf_loss: 7.898406505584717
#     grad_time_ms: 11727.137
#     load_time_ms: 5.277
#     num_steps_sampled: 1166559
#     num_steps_trained: 1166559
#     sample_time_ms: 9431.949
#     update_time_ms: 9.405
#   iterations_since_restore: 17
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 391.5405607223511
#   time_this_iter_s: 20.666922330856323
#   time_total_s: 391.5405607223511
#   timestamp: 1555625587
#   timesteps_since_restore: 1166559
#   timesteps_this_iter: 66686
#   timesteps_total: 1166559
#   training_iteration: 17
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.2/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 391 s, 17 iter, 1166559 ts, 708 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-13-27
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 859.8649373384592
#   episode_reward_mean: 709.6855721047459
#   episode_reward_min: 631.9345002521995
#   episodes_this_iter: 28
#   episodes_total: 370
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.000781250128056854
#       cur_lr: 0.0005000000237487257
#       entropy: 1.307193636894226
#       kl: 0.0068894727155566216
#       policy_loss: -0.0014315242879092693
#       total_loss: 9.962178230285645
#       vf_explained_var: 0.1975688934326172
#       vf_loss: 9.963604927062988
#     grad_time_ms: 11642.873
#     load_time_ms: 5.224
#     num_steps_sampled: 1233112
#     num_steps_trained: 1233112
#     sample_time_ms: 9456.205
#     update_time_ms: 9.491
#   iterations_since_restore: 18
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 411.75592732429504
#   time_this_iter_s: 20.21536660194397
#   time_total_s: 411.75592732429504
#   timestamp: 1555625607
#   timesteps_since_restore: 1233112
#   timesteps_this_iter: 66553
#   timesteps_total: 1233112
#   training_iteration: 18
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.2/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 411 s, 18 iter, 1233112 ts, 710 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-13-48
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 859.8649373384592
#   episode_reward_mean: 713.9495546168265
#   episode_reward_min: 631.9345002521995
#   episodes_this_iter: 23
#   episodes_total: 393
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.0007812500698491931
#       cur_lr: 0.0005000000237487257
#       entropy: 1.2977361679077148
#       kl: 0.008466006256639957
#       policy_loss: -0.0017513647908344865
#       total_loss: 8.044719696044922
#       vf_explained_var: 0.17817899584770203
#       vf_loss: 8.046463966369629
#     grad_time_ms: 11515.994
#     load_time_ms: 5.122
#     num_steps_sampled: 1301429
#     num_steps_trained: 1301429
#     sample_time_ms: 9426.999
#     update_time_ms: 9.594
#   iterations_since_restore: 19
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 432.7315595149994
#   time_this_iter_s: 20.975632190704346
#   time_total_s: 432.7315595149994
#   timestamp: 1555625628
#   timesteps_since_restore: 1301429
#   timesteps_this_iter: 68317
#   timesteps_total: 1301429
#   training_iteration: 19
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.2/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 432 s, 19 iter, 1301429 ts, 714 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-14-09
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 859.8649373384592
#   episode_reward_mean: 710.2444168190901
#   episode_reward_min: 621.8251309437372
#   episodes_this_iter: 26
#   episodes_total: 419
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.0007812500698491931
#       cur_lr: 0.0005000000237487257
#       entropy: 1.2978847026824951
#       kl: 0.006731091532856226
#       policy_loss: -0.0011121233692392707
#       total_loss: 9.09591293334961
#       vf_explained_var: 0.2020627111196518
#       vf_loss: 9.097020149230957
#     grad_time_ms: 11561.255
#     load_time_ms: 4.93
#     num_steps_sampled: 1367501
#     num_steps_trained: 1367501
#     sample_time_ms: 9364.261
#     update_time_ms: 9.485
#   iterations_since_restore: 20
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 454.37438464164734
#   time_this_iter_s: 21.64282512664795
#   time_total_s: 454.37438464164734
#   timestamp: 1555625649
#   timesteps_since_restore: 1367501
#   timesteps_this_iter: 66072
#   timesteps_total: 1367501
#   training_iteration: 20
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.2/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 454 s, 20 iter, 1367501 ts, 710 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-14-32
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 840.9027383252036
#   episode_reward_mean: 711.6166078663525
#   episode_reward_min: 621.8251309437372
#   episodes_this_iter: 21
#   episodes_total: 440
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.000781250128056854
#       cur_lr: 0.0005000000237487257
#       entropy: 1.2897844314575195
#       kl: 0.0048728627152740955
#       policy_loss: -0.0004484406963456422
#       total_loss: 7.650310039520264
#       vf_explained_var: 0.24819177389144897
#       vf_loss: 7.650754451751709
#     grad_time_ms: 11690.804
#     load_time_ms: 4.999
#     num_steps_sampled: 1433368
#     num_steps_trained: 1433368
#     sample_time_ms: 9337.219
#     update_time_ms: 9.423
#   iterations_since_restore: 21
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 476.6107177734375
#   time_this_iter_s: 22.23633313179016
#   time_total_s: 476.6107177734375
#   timestamp: 1555625672
#   timesteps_since_restore: 1433368
#   timesteps_this_iter: 65867
#   timesteps_total: 1433368
#   training_iteration: 21
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.2/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 476 s, 21 iter, 1433368 ts, 712 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-14-53
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 855.3429969939107
#   episode_reward_mean: 713.2385660898317
#   episode_reward_min: 621.8251309437372
#   episodes_this_iter: 15
#   episodes_total: 455
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.00039062503492459655
#       cur_lr: 0.0005000000237487257
#       entropy: 1.2759029865264893
#       kl: 0.005283272359520197
#       policy_loss: -0.0005227806977927685
#       total_loss: 6.516145706176758
#       vf_explained_var: 0.24243415892124176
#       vf_loss: 6.516665935516357
#     grad_time_ms: 11659.98
#     load_time_ms: 4.958
#     num_steps_sampled: 1500225
#     num_steps_trained: 1500225
#     sample_time_ms: 9322.076
#     update_time_ms: 9.489
#   iterations_since_restore: 22
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 498.1092920303345
#   time_this_iter_s: 21.498574256896973
#   time_total_s: 498.1092920303345
#   timestamp: 1555625693
#   timesteps_since_restore: 1500225
#   timesteps_this_iter: 66857
#   timesteps_total: 1500225
#   training_iteration: 22
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.2/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 498 s, 22 iter, 1500225 ts, 713 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-15-13
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 868.5971910197102
#   episode_reward_mean: 713.5547757282911
#   episode_reward_min: 621.8251309437372
#   episodes_this_iter: 23
#   episodes_total: 478
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.00039062503492459655
#       cur_lr: 0.0005000000237487257
#       entropy: 1.2635337114334106
#       kl: 0.0057465448044240475
#       policy_loss: -0.00028599120560102165
#       total_loss: 8.517066955566406
#       vf_explained_var: 0.19333012402057648
#       vf_loss: 8.517350196838379
#     grad_time_ms: 11520.611
#     load_time_ms: 4.798
#     num_steps_sampled: 1565056
#     num_steps_trained: 1565056
#     sample_time_ms: 9310.619
#     update_time_ms: 9.538
#   iterations_since_restore: 23
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 517.9948861598969
#   time_this_iter_s: 19.885594129562378
#   time_total_s: 517.9948861598969
#   timestamp: 1555625713
#   timesteps_since_restore: 1565056
#   timesteps_this_iter: 64831
#   timesteps_total: 1565056
#   training_iteration: 23
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.3/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 517 s, 23 iter, 1565056 ts, 714 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-15-36
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 868.5971910197102
#   episode_reward_mean: 715.556691404704
#   episode_reward_min: 621.8251309437372
#   episodes_this_iter: 23
#   episodes_total: 501
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.00039062503492459655
#       cur_lr: 0.0005000000237487257
#       entropy: 1.243181824684143
#       kl: 0.006460009142756462
#       policy_loss: -0.0005593240493908525
#       total_loss: 8.847055435180664
#       vf_explained_var: 0.1809871792793274
#       vf_loss: 8.847613334655762
#     grad_time_ms: 11778.269
#     load_time_ms: 5.101
#     num_steps_sampled: 1631942
#     num_steps_trained: 1631942
#     sample_time_ms: 9320.717
#     update_time_ms: 9.709
#   iterations_since_restore: 24
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 541.0410363674164
#   time_this_iter_s: 23.04615020751953
#   time_total_s: 541.0410363674164
#   timestamp: 1555625736
#   timesteps_since_restore: 1631942
#   timesteps_this_iter: 66886
#   timesteps_total: 1631942
#   training_iteration: 24
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.3/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 541 s, 24 iter, 1631942 ts, 716 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-15-58
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 868.5971910197102
#   episode_reward_mean: 721.2379721240586
#   episode_reward_min: 632.431694521841
#   episodes_this_iter: 21
#   episodes_total: 522
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.000390625064028427
#       cur_lr: 0.0005000000237487257
#       entropy: 1.2261481285095215
#       kl: 0.007468735333532095
#       policy_loss: -0.0009513133554719388
#       total_loss: 8.856468200683594
#       vf_explained_var: 0.20327399671077728
#       vf_loss: 8.857416152954102
#     grad_time_ms: 11884.53
#     load_time_ms: 5.127
#     num_steps_sampled: 1698474
#     num_steps_trained: 1698474
#     sample_time_ms: 9366.314
#     update_time_ms: 9.73
#   iterations_since_restore: 25
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 563.0178024768829
#   time_this_iter_s: 21.976766109466553
#   time_total_s: 563.0178024768829
#   timestamp: 1555625758
#   timesteps_since_restore: 1698474
#   timesteps_this_iter: 66532
#   timesteps_total: 1698474
#   training_iteration: 25
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.3/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 563 s, 25 iter, 1698474 ts, 721 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-16-19
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 868.5971910197102
#   episode_reward_mean: 724.4744369864676
#   episode_reward_min: 631.9946449441444
#   episodes_this_iter: 20
#   episodes_total: 542
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.000390625064028427
#       cur_lr: 0.0005000000237487257
#       entropy: 1.2224053144454956
#       kl: 0.005932185333222151
#       policy_loss: -0.0002478614042047411
#       total_loss: 7.558536052703857
#       vf_explained_var: 0.21384111046791077
#       vf_loss: 7.55878210067749
#     grad_time_ms: 11857.626
#     load_time_ms: 5.151
#     num_steps_sampled: 1765601
#     num_steps_trained: 1765601
#     sample_time_ms: 9350.731
#     update_time_ms: 9.711
#   iterations_since_restore: 26
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 583.9360973834991
#   time_this_iter_s: 20.91829490661621
#   time_total_s: 583.9360973834991
#   timestamp: 1555625779
#   timesteps_since_restore: 1765601
#   timesteps_this_iter: 67127
#   timesteps_total: 1765601
#   training_iteration: 26
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.3/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 583 s, 26 iter, 1765601 ts, 724 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-16-41
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 868.5971910197102
#   episode_reward_mean: 722.3304061058005
#   episode_reward_min: 631.9946449441444
#   episodes_this_iter: 26
#   episodes_total: 568
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.00039062503492459655
#       cur_lr: 0.0005000000237487257
#       entropy: 1.2027122974395752
#       kl: 0.0070924703031778336
#       policy_loss: -0.0005793643649667501
#       total_loss: 9.922377586364746
#       vf_explained_var: 0.143696591258049
#       vf_loss: 9.922953605651855
#     grad_time_ms: 11885.703
#     load_time_ms: 5.063
#     num_steps_sampled: 1833080
#     num_steps_trained: 1833080
#     sample_time_ms: 9408.815
#     update_time_ms: 9.736
#   iterations_since_restore: 27
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 605.4546775817871
#   time_this_iter_s: 21.518580198287964
#   time_total_s: 605.4546775817871
#   timestamp: 1555625801
#   timesteps_since_restore: 1833080
#   timesteps_this_iter: 67479
#   timesteps_total: 1833080
#   training_iteration: 27
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.3/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 605 s, 27 iter, 1833080 ts, 722 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-17-02
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 861.3077901660764
#   episode_reward_mean: 722.6588545890979
#   episode_reward_min: 631.9946449441444
#   episodes_this_iter: 23
#   episodes_total: 591
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.00039062503492459655
#       cur_lr: 0.0005000000237487257
#       entropy: 1.1861023902893066
#       kl: 0.0063932836055755615
#       policy_loss: -0.0005071127088740468
#       total_loss: 8.176559448242188
#       vf_explained_var: 0.16775523126125336
#       vf_loss: 8.17706298828125
#     grad_time_ms: 11977.088
#     load_time_ms: 5.152
#     num_steps_sampled: 1900471
#     num_steps_trained: 1900471
#     sample_time_ms: 9397.939
#     update_time_ms: 9.675
#   iterations_since_restore: 28
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 626.4836573600769
#   time_this_iter_s: 21.028979778289795
#   time_total_s: 626.4836573600769
#   timestamp: 1555625822
#   timesteps_since_restore: 1900471
#   timesteps_this_iter: 67391
#   timesteps_total: 1900471
#   training_iteration: 28
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.3/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 626 s, 28 iter, 1900471 ts, 723 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-17-24
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 861.3077901660764
#   episode_reward_mean: 720.2278319867764
#   episode_reward_min: 631.9946449441444
#   episodes_this_iter: 25
#   episodes_total: 616
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.00039062503492459655
#       cur_lr: 0.0005000000237487257
#       entropy: 1.1753616333007812
#       kl: 0.00643664738163352
#       policy_loss: 2.2642672774964012e-05
#       total_loss: 8.979217529296875
#       vf_explained_var: 0.17340052127838135
#       vf_loss: 8.979192733764648
#     grad_time_ms: 12047.03
#     load_time_ms: 5.136
#     num_steps_sampled: 1967171
#     num_steps_trained: 1967171
#     sample_time_ms: 9425.975
#     update_time_ms: 9.647
#   iterations_since_restore: 29
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 648.4391250610352
#   time_this_iter_s: 21.955467700958252
#   time_total_s: 648.4391250610352
#   timestamp: 1555625844
#   timesteps_since_restore: 1967171
#   timesteps_this_iter: 66700
#   timesteps_total: 1967171
#   training_iteration: 29
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.3/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 648 s, 29 iter, 1967171 ts, 720 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-17-44
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 835.9112233653974
#   episode_reward_mean: 718.1810519329988
#   episode_reward_min: 648.0373242895499
#   episodes_this_iter: 20
#   episodes_total: 636
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.00039062509313225746
#       cur_lr: 0.0005000000237487257
#       entropy: 1.166360855102539
#       kl: 0.00601429957896471
#       policy_loss: -0.0001423533831257373
#       total_loss: 7.862285137176514
#       vf_explained_var: 0.23604048788547516
#       vf_loss: 7.862424373626709
#     grad_time_ms: 11958.833
#     load_time_ms: 5.161
#     num_steps_sampled: 2034145
#     num_steps_trained: 2034145
#     sample_time_ms: 9431.007
#     update_time_ms: 9.663
#   iterations_since_restore: 30
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 669.2410216331482
#   time_this_iter_s: 20.801896572113037
#   time_total_s: 669.2410216331482
#   timestamp: 1555625864
#   timesteps_since_restore: 2034145
#   timesteps_this_iter: 66974
#   timesteps_total: 2034145
#   training_iteration: 30
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.3/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 669 s, 30 iter, 2034145 ts, 718 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-18_22-18-05
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 835.9112233653974
#   episode_reward_mean: 721.5047835533755
#   episode_reward_min: 635.3811509067392
#   episodes_this_iter: 18
#   episodes_total: 654
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.00039062503492459655
#       cur_lr: 0.0005000000237487257
#       entropy: 1.1538437604904175
#       kl: 0.0065783169120550156
#       policy_loss: -0.0009154014987871051
#       total_loss: 7.0988383293151855
#       vf_explained_var: 0.22919858992099762
#       vf_loss: 7.099751949310303
#     grad_time_ms: 11777.221
#     load_time_ms: 4.961
#     num_steps_sampled: 2100922
#     num_steps_trained: 2100922
#     sample_time_ms: 9440.155
#     update_time_ms: 9.71
#   iterations_since_restore: 31
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 689.747935295105
#   time_this_iter_s: 20.506913661956787
#   time_total_s: 689.747935295105
#   timestamp: 1555625885
#   timesteps_since_restore: 2100922
#   timesteps_this_iter: 66777
#   timesteps_total: 2100922
#   training_iteration: 31
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 18.4/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
# ...
# Memory usage on this node: 23.3/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 10455 s, 490 iter, 33072416 ts, 735 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-19_01-01-22
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 807.9285036023809
#   episode_reward_mean: 734.5280223900616
#   episode_reward_min: 661.4798604808495
#   episodes_this_iter: 23
#   episodes_total: 10607
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.2565784454345703
#       cur_lr: 0.0005000000237487257
#       entropy: 0.09825630486011505
#       kl: 0.010603268630802631
#       policy_loss: -0.0003471397212706506
#       total_loss: 7.83917236328125
#       vf_explained_var: 0.23759710788726807
#       vf_loss: 7.836799144744873
#     grad_time_ms: 11696.342
#     load_time_ms: 4.851
#     num_steps_sampled: 33139450
#     num_steps_trained: 33139450
#     sample_time_ms: 9489.928
#     update_time_ms: 9.174
#   iterations_since_restore: 491
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 10477.400655269623
#   time_this_iter_s: 21.836572647094727
#   time_total_s: 10477.400655269623
#   timestamp: 1555635682
#   timesteps_since_restore: 33139450
#   timesteps_this_iter: 67034
#   timesteps_total: 33139450
#   training_iteration: 491
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 23.3/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 10477 s, 491 iter, 33139450 ts, 735 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-19_01-01-43
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 807.9285036023809
#   episode_reward_mean: 733.8795744399495
#   episode_reward_min: 661.4798604808495
#   episodes_this_iter: 18
#   episodes_total: 10625
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.2565784454345703
#       cur_lr: 0.0005000000237487257
#       entropy: 0.09114661812782288
#       kl: 0.01286035031080246
#       policy_loss: 0.0006563527276739478
#       total_loss: 5.714059352874756
#       vf_explained_var: 0.22532406449317932
#       vf_loss: 5.7101030349731445
#     grad_time_ms: 11708.445
#     load_time_ms: 4.806
#     num_steps_sampled: 33207273
#     num_steps_trained: 33207273
#     sample_time_ms: 9509.579
#     update_time_ms: 9.164
#   iterations_since_restore: 492
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 10498.440574407578
#   time_this_iter_s: 21.039919137954712
#   time_total_s: 10498.440574407578
#   timestamp: 1555635703
#   timesteps_since_restore: 33207273
#   timesteps_this_iter: 67823
#   timesteps_total: 33207273
#   training_iteration: 492
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 23.4/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 10498 s, 492 iter, 33207273 ts, 734 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-19_01-02-03
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 807.9285036023809
#   episode_reward_mean: 732.399529665289
#   episode_reward_min: 661.4798604808495
#   episodes_this_iter: 24
#   episodes_total: 10649
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.2565784454345703
#       cur_lr: 0.0005000000237487257
#       entropy: 0.08584172278642654
#       kl: 0.011561415158212185
#       policy_loss: -0.00043632651795633137
#       total_loss: 7.630176067352295
#       vf_explained_var: 0.19686436653137207
#       vf_loss: 7.627645492553711
#     grad_time_ms: 11648.021
#     load_time_ms: 4.708
#     num_steps_sampled: 33274601
#     num_steps_trained: 33274601
#     sample_time_ms: 9509.677
#     update_time_ms: 9.266
#   iterations_since_restore: 493
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 10518.197955608368
#   time_this_iter_s: 19.757381200790405
#   time_total_s: 10518.197955608368
#   timestamp: 1555635723
#   timesteps_since_restore: 33274601
#   timesteps_this_iter: 67328
#   timesteps_total: 33274601
#   training_iteration: 493
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 23.4/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 10518 s, 493 iter, 33274601 ts, 732 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-19_01-02-25
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 807.9285036023809
#   episode_reward_mean: 731.2345264762196
#   episode_reward_min: 659.188323991581
#   episodes_this_iter: 24
#   episodes_total: 10673
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.2565784454345703
#       cur_lr: 0.0005000000237487257
#       entropy: 0.1184268668293953
#       kl: 0.012873843312263489
#       policy_loss: 0.0007378118461929262
#       total_loss: 7.384084224700928
#       vf_explained_var: 0.19751915335655212
#       vf_loss: 7.380042552947998
#     grad_time_ms: 11734.755
#     load_time_ms: 4.722
#     num_steps_sampled: 33342152
#     num_steps_trained: 33342152
#     sample_time_ms: 9517.56
#     update_time_ms: 9.471
#   iterations_since_restore: 494
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 10539.727928876877
#   time_this_iter_s: 21.52997326850891
#   time_total_s: 10539.727928876877
#   timestamp: 1555635745
#   timesteps_since_restore: 33342152
#   timesteps_this_iter: 67551
#   timesteps_total: 33342152
#   training_iteration: 494
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 23.4/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 10539 s, 494 iter, 33342152 ts, 731 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-19_01-02-46
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 807.9285036023809
#   episode_reward_mean: 728.9230401468981
#   episode_reward_min: 659.188323991581
#   episodes_this_iter: 18
#   episodes_total: 10691
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.2565784454345703
#       cur_lr: 0.0005000000237487257
#       entropy: 0.09173350036144257
#       kl: 0.010836579836905003
#       policy_loss: -1.0634499631123617e-05
#       total_loss: 5.865492820739746
#       vf_explained_var: 0.22667309641838074
#       vf_loss: 5.862723350524902
#     grad_time_ms: 11713.37
#     load_time_ms: 4.528
#     num_steps_sampled: 33410290
#     num_steps_trained: 33410290
#     sample_time_ms: 9480.182
#     update_time_ms: 9.508
#   iterations_since_restore: 495
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 10560.589632987976
#   time_this_iter_s: 20.861704111099243
#   time_total_s: 10560.589632987976
#   timestamp: 1555635766
#   timesteps_since_restore: 33410290
#   timesteps_this_iter: 68138
#   timesteps_total: 33410290
#   training_iteration: 495
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 23.4/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 10560 s, 495 iter, 33410290 ts, 729 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-19_01-03-06
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 803.1703184778688
#   episode_reward_mean: 727.1500605049847
#   episode_reward_min: 646.9867940586073
#   episodes_this_iter: 21
#   episodes_total: 10712
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.2565784454345703
#       cur_lr: 0.0005000000237487257
#       entropy: 0.09073861688375473
#       kl: 0.012112079188227654
#       policy_loss: 0.001661157002672553
#       total_loss: 6.724101543426514
#       vf_explained_var: 0.23891711235046387
#       vf_loss: 6.719333171844482
#     grad_time_ms: 11622.955
#     load_time_ms: 4.35
#     num_steps_sampled: 33477630
#     num_steps_trained: 33477630
#     sample_time_ms: 9456.753
#     update_time_ms: 9.566
#   iterations_since_restore: 496
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 10580.998185634613
#   time_this_iter_s: 20.408552646636963
#   time_total_s: 10580.998185634613
#   timestamp: 1555635786
#   timesteps_since_restore: 33477630
#   timesteps_this_iter: 67340
#   timesteps_total: 33477630
#   training_iteration: 496
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 23.4/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 10580 s, 496 iter, 33477630 ts, 727 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-19_01-03-27
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 809.0776582484276
#   episode_reward_mean: 730.3101971806304
#   episode_reward_min: 646.9867940586073
#   episodes_this_iter: 26
#   episodes_total: 10738
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.2565784454345703
#       cur_lr: 0.0005000000237487257
#       entropy: 0.10504697263240814
#       kl: 0.012071200646460056
#       policy_loss: -1.553555739519652e-05
#       total_loss: 7.724158763885498
#       vf_explained_var: 0.2208826243877411
#       vf_loss: 7.721076965332031
#     grad_time_ms: 11575.014
#     load_time_ms: 4.385
#     num_steps_sampled: 33543737
#     num_steps_trained: 33543737
#     sample_time_ms: 9463.375
#     update_time_ms: 9.667
#   iterations_since_restore: 497
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 10601.875657320023
#   time_this_iter_s: 20.877471685409546
#   time_total_s: 10601.875657320023
#   timestamp: 1555635807
#   timesteps_since_restore: 33543737
#   timesteps_this_iter: 66107
#   timesteps_total: 33543737
#   training_iteration: 497
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 23.4/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 10601 s, 497 iter, 33543737 ts, 730 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-19_01-03-48
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 809.146224441628
#   episode_reward_mean: 731.6289687465187
#   episode_reward_min: 646.9867940586073
#   episodes_this_iter: 18
#   episodes_total: 10756
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.2565784454345703
#       cur_lr: 0.0005000000237487257
#       entropy: 0.11591740697622299
#       kl: 0.010745005682110786
#       policy_loss: 0.0012348905438557267
#       total_loss: 5.656045436859131
#       vf_explained_var: 0.2534455358982086
#       vf_loss: 5.6520538330078125
#     grad_time_ms: 11507.883
#     load_time_ms: 4.49
#     num_steps_sampled: 33612163
#     num_steps_trained: 33612163
#     sample_time_ms: 9499.674
#     update_time_ms: 9.799
#   iterations_since_restore: 498
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 10622.643775463104
#   time_this_iter_s: 20.768118143081665
#   time_total_s: 10622.643775463104
#   timestamp: 1555635828
#   timesteps_since_restore: 33612163
#   timesteps_this_iter: 68426
#   timesteps_total: 33612163
#   training_iteration: 498
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 23.4/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 10622 s, 498 iter, 33612163 ts, 732 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-19_01-04-09
#   done: false
#   episode_len_mean: 750.0
#   episode_reward_max: 809.146224441628
#   episode_reward_mean: 728.4292390031237
#   episode_reward_min: 646.9867940586073
#   episodes_this_iter: 24
#   episodes_total: 10780
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.2565784156322479
#       cur_lr: 0.0005000000237487257
#       entropy: 0.10710359364748001
#       kl: 0.010123347863554955
#       policy_loss: 9.109894745051861e-05
#       total_loss: 7.883522033691406
#       vf_explained_var: 0.23232530057430267
#       vf_loss: 7.880834102630615
#     grad_time_ms: 11469.204
#     load_time_ms: 4.694
#     num_steps_sampled: 33679397
#     num_steps_trained: 33679397
#     sample_time_ms: 9490.997
#     update_time_ms: 9.738
#   iterations_since_restore: 499
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 10644.023191213608
#   time_this_iter_s: 21.37941575050354
#   time_total_s: 10644.023191213608
#   timestamp: 1555635849
#   timesteps_since_restore: 33679397
#   timesteps_this_iter: 67234
#   timesteps_total: 33679397
#   training_iteration: 499
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 50/63 CPUs, 0/0 GPUs
# Memory usage on this node: 23.4/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=361], 10644 s, 499 iter, 33679397 ts, 728 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-19_01-04-32
#   done: true
#   episode_len_mean: 750.0
#   episode_reward_max: 809.146224441628
#   episode_reward_mean: 731.092174759964
#   episode_reward_min: 646.9867940586073
#   episodes_this_iter: 22
#   episodes_total: 10802
#   experiment_id: ca1ade39f0914adcb484936affff8a1a
#   hostname: flow-main
#   info:
#     default:
#       cur_kl_coeff: 0.2565784156322479
#       cur_lr: 0.0005000000237487257
#       entropy: 0.13250085711479187
#       kl: 0.010915374383330345
#       policy_loss: -0.0012521513272076845
#       total_loss: 6.6443610191345215
#       vf_explained_var: 0.27706480026245117
#       vf_loss: 6.642812728881836
#     grad_time_ms: 11483.363
#     load_time_ms: 4.519
#     num_steps_sampled: 33746661
#     num_steps_trained: 33746661
#     sample_time_ms: 9524.754
#     update_time_ms: 9.719
#   iterations_since_restore: 500
#   node_ip: 10.138.0.2
#   num_metric_batches_dropped: 0
#   pid: 361
#   policy_reward_mean: {}
#   time_since_restore: 10666.677580356598
#   time_this_iter_s: 22.654389142990112
#   time_total_s: 10666.677580356598
#   timestamp: 1555635872
#   timesteps_since_restore: 33746661
#   timesteps_this_iter: 67264
#   timesteps_total: 33746661
#   training_iteration: 500
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 0/63 CPUs, 0/0 GPUs
# Memory usage on this node: 23.2/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# TERMINATED trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	TERMINATED [pid=361], 10666 s, 500 iter, 33746661 ts, 731 rew
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 0/63 CPUs, 0/0 GPUs
# Memory usage on this node: 23.2/94.8 GB
# Result logdir: /headless/ray_results/multi_merge
# TERMINATED trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	TERMINATED [pid=361], 10666 s, 500 iter, 33746661 ts, 731 rew
