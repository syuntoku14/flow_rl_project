# %%
import json
import argparse
from itertools import product
import numpy as np
from logging import getLogger

import ray
try:
    from ray.rllib.agents.agent import get_agent_class
except ImportError:
    from ray.rllib.agents.registry import get_agent_class
from ray.tune import Experiment, run_experiments
from ray.tune.registry import register_env

from flow.utils.registry import make_create_env
from flow.utils.rllib import FlowParamsEncoder
benchmark_name = 'multi_merge'
# number of rollouts per training iteration
num_rollouts = 1
# number of parallel workers
num_cpus = 2

# %%
# Import the benchmark and fetch its flow_params
benchmark = __import__(
    "flow.benchmarks.%s" % benchmark_name, fromlist=["flow_params"])
flow_params = benchmark.flow_params

# get the env name and a creator for the environment
create_env, env_name = make_create_env(params=flow_params, version=0)

register_env(env_name, create_env)

# initialize a ray instance
ray.init()

alg_run = "PPO"

horizon = flow_params["env"].horizon
agent_cls = get_agent_class(alg_run)
config = agent_cls._default_config.copy()
config["num_workers"] = min(num_cpus, num_rollouts)
config["train_batch_size"] = horizon * num_rollouts
config["use_gae"] = True
config["horizon"] = horizon
gae_lambda = 0.97
step_size = 5e-4
config["lambda"] = gae_lambda
config["lr"] = step_size
config["vf_clip_param"] = 1e6
config["num_sgd_iter"] = 10
config['clip_actions'] = False  # FIXME(ev) temporary ray bug
config["model"]["fcnet_hiddens"] = [100, 50, 25]
config["observation_filter"] = "NoFilter"
config["entropy_coeff"] = 0.0

# save the flow params for replay
flow_json = json.dumps(
    flow_params, cls=FlowParamsEncoder, sort_keys=True, indent=4)
config['env_config']['flow_params'] = flow_json
config['env_config']['run'] = alg_run
# Out:
# Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-04-25_22-58-02_1112/logs.
# Waiting for redis server at 127.0.0.1:29882 to respond...
# Waiting for redis server at 127.0.0.1:42786 to respond...
# Starting the Plasma object store with 13.355121049 GB memory using /dev/shm.
#
# ======================================================================
# View the web UI at http://localhost:8888/notebooks/ray_ui.ipynb?token=a8bc63089d4e8b15c268160cd9169712900c9505fae01a8b
# ======================================================================

# %%
def on_episode_start(info):
    episode = info["episode"]
    episode.user_data["cost1"] = []
    episode.user_data["cost2"] = []


def on_episode_step(info):
    env = info["env"]
    _, _, _, info, _ = env.poll()
    # episode.user_data["pole_angles"].append(pole_angle)


def on_episode_end(info):
    pass
    # episode = info["episode"]
    # pole_angle = np.mean(episode.user_data["pole_angles"])
    # print("episode {} ended with length {} and pole angles {}".format(
    #     episode.episode_id, episode.length, pole_angle))
    # episode.custom_metrics["pole_angle"] = pole_angle

# %%
config['callbacks']['on_episode_start'] = ray.tune.function(on_episode_start)
config['callbacks']['on_episode_step'] = ray.tune.function(on_episode_step)
config['callbacks']['on_episode_end'] = ray.tune.function(on_episode_end)

# %%
# tunning parameters
eta = [[1.0, 0.3]]
reward_scale = [1.0]#, 0.5]
t_min = [3.0]# , 5.0, 10.0]

exp_tag = {
    "run": alg_run,
    "env": env_name,
    "config": {
        **config
    },
    "checkpoint_freq": 25,
    "max_failures": 999,
    "stop": {
        "training_iteration": 10
    },
    "num_samples": 1,
}

trials = run_experiments(
    {'test':exp_tag}
)
# Out:
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 0/4 CPUs, 0/1 GPUs
# Memory usage on this node: 5.1/33.4 GB
#
# Created LogSyncer for /headless/ray_results/test/PPO_MultiWaveAttenuationMergePOEnv-v0_0_2019-04-25_22-58-466sm12mxd ->
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 2/4 CPUs, 0/1 GPUs
# Memory usage on this node: 5.1/33.4 GB
# Result logdir: /headless/ray_results/test
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-25_22-59-22
#   done: false
#   episode_len_mean: 350.0
#   episode_reward_max: 290.93073690926167
#   episode_reward_mean: 290.93073690926167
#   episode_reward_min: 290.93073690926167
#   episodes_this_iter: 1
#   episodes_total: 1
#   experiment_id: d54538960e9648069d9a1dea8bd3d931
#   hostname: kronos
#   info:
#     default:
#       cur_kl_coeff: 0.20000000298023224
#       cur_lr: 0.0005000000237487257
#       entropy: 1.4203226566314697
#       kl: 0.0022588414140045643
#       policy_loss: -0.00039836912765167654
#       total_loss: 23.741775512695312
#       vf_explained_var: 0.026136290282011032
#       vf_loss: 23.74172019958496
#     grad_time_ms: 716.693
#     load_time_ms: 44.985
#     num_steps_sampled: 1334
#     num_steps_trained: 1334
#     sample_time_ms: 15849.923
#     update_time_ms: 554.177
#   iterations_since_restore: 1
#   node_ip: 169.237.32.118
#   num_metric_batches_dropped: 0
#   pid: 1154
#   policy_reward_mean: {}
#   time_since_restore: 17.212656259536743
#   time_this_iter_s: 17.212656259536743
#   time_total_s: 17.212656259536743
#   timestamp: 1556233162
#   timesteps_since_restore: 1334
#   timesteps_this_iter: 1334
#   timesteps_total: 1334
#   training_iteration: 1
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 2/4 CPUs, 0/1 GPUs
# Memory usage on this node: 5.8/33.4 GB
# Result logdir: /headless/ray_results/test
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=1154], 17 s, 1 iter, 1334 ts, 291 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-25_22-59-28
#   done: false
#   episode_len_mean: 350.0
#   episode_reward_max: 290.93073690926167
#   episode_reward_mean: 212.31186227662664
#   episode_reward_min: 133.69298764399164
#   episodes_this_iter: 1
#   episodes_total: 2
#   experiment_id: d54538960e9648069d9a1dea8bd3d931
#   hostname: kronos
#   info:
#     default:
#       cur_kl_coeff: 0.10000000149011612
#       cur_lr: 0.0005000000237487257
#       entropy: 1.4054818153381348
#       kl: 0.006757889874279499
#       policy_loss: -0.019901135936379433
#       total_loss: 15.309724807739258
#       vf_explained_var: 0.03631759434938431
#       vf_loss: 15.328950881958008
#     grad_time_ms: 500.259
#     load_time_ms: 23.271
#     num_steps_sampled: 2541
#     num_steps_trained: 2541
#     sample_time_ms: 10487.664
#     update_time_ms: 280.094
#   iterations_since_restore: 2
#   node_ip: 169.237.32.118
#   num_metric_batches_dropped: 0
#   pid: 1154
#   policy_reward_mean: {}
#   time_since_restore: 22.634580612182617
#   time_this_iter_s: 5.421924352645874
#   time_total_s: 22.634580612182617
#   timestamp: 1556233168
#   timesteps_since_restore: 2541
#   timesteps_this_iter: 1207
#   timesteps_total: 2541
#   training_iteration: 2
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 2/4 CPUs, 0/1 GPUs
# Memory usage on this node: 5.8/33.4 GB
# Result logdir: /headless/ray_results/test
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=1154], 22 s, 2 iter, 2541 ts, 212 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-25_22-59-33
#   done: false
#   episode_len_mean: 350.0
#   episode_reward_max: 290.93073690926167
#   episode_reward_mean: 196.59482785889023
#   episode_reward_min: 133.69298764399164
#   episodes_this_iter: 1
#   episodes_total: 3
#   experiment_id: d54538960e9648069d9a1dea8bd3d931
#   hostname: kronos
#   info:
#     default:
#       cur_kl_coeff: 0.10000000149011612
#       cur_lr: 0.0005000000237487257
#       entropy: 1.4094185829162598
#       kl: 0.025280270725488663
#       policy_loss: -0.024975020438432693
#       total_loss: 25.99105453491211
#       vf_explained_var: 0.09000076353549957
#       vf_loss: 26.013500213623047
#     grad_time_ms: 395.348
#     load_time_ms: 15.93
#     num_steps_sampled: 3617
#     num_steps_trained: 3617
#     sample_time_ms: 8691.929
#     update_time_ms: 188.675
#   iterations_since_restore: 3
#   node_ip: 169.237.32.118
#   num_metric_batches_dropped: 0
#   pid: 1154
#   policy_reward_mean: {}
#   time_since_restore: 27.93308687210083
#   time_this_iter_s: 5.298506259918213
#   time_total_s: 27.93308687210083
#   timestamp: 1556233173
#   timesteps_since_restore: 3617
#   timesteps_this_iter: 1076
#   timesteps_total: 3617
#   training_iteration: 3
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 2/4 CPUs, 0/1 GPUs
# Memory usage on this node: 5.9/33.4 GB
# Result logdir: /headless/ray_results/test
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=1154], 27 s, 3 iter, 3617 ts, 197 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-25_22-59-43
#   done: false
#   episode_len_mean: 350.0
#   episode_reward_max: 444.97251704490907
#   episode_reward_mean: 278.2602113922866
#   episode_reward_min: 133.69298764399164
#   episodes_this_iter: 1
#   episodes_total: 5
#   experiment_id: d54538960e9648069d9a1dea8bd3d931
#   hostname: kronos
#   info:
#     default:
#       cur_kl_coeff: 0.15000000596046448
#       cur_lr: 0.0005000000237487257
#       entropy: 1.3606350421905518
#       kl: 0.007085037883371115
#       policy_loss: -0.0048895631916821
#       total_loss: 41.21182632446289
#       vf_explained_var: 0.09243632107973099
#       vf_loss: 41.21565246582031
#     grad_time_ms: 306.687
#     load_time_ms: 10.023
#     num_steps_sampled: 5729
#     num_steps_trained: 5729
#     sample_time_ms: 7183.364
#     update_time_ms: 114.979
#   iterations_since_restore: 5
#   node_ip: 169.237.32.118
#   num_metric_batches_dropped: 0
#   pid: 1154
#   policy_reward_mean: {}
#   time_since_restore: 38.14409875869751
#   time_this_iter_s: 6.027584552764893
#   time_total_s: 38.14409875869751
#   timestamp: 1556233183
#   timesteps_since_restore: 5729
#   timesteps_this_iter: 1262
#   timesteps_total: 5729
#   training_iteration: 5
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 2/4 CPUs, 0/1 GPUs
# Memory usage on this node: 5.9/33.4 GB
# Result logdir: /headless/ray_results/test
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=1154], 38 s, 5 iter, 5729 ts, 278 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-25_22-59-49
#   done: false
#   episode_len_mean: 350.0
#   episode_reward_max: 489.31080349554145
#   episode_reward_mean: 313.43531007616247
#   episode_reward_min: 133.69298764399164
#   episodes_this_iter: 1
#   episodes_total: 6
#   experiment_id: d54538960e9648069d9a1dea8bd3d931
#   hostname: kronos
#   info:
#     default:
#       cur_kl_coeff: 0.15000000596046448
#       cur_lr: 0.0005000000237487257
#       entropy: 1.307259202003479
#       kl: 0.0059182243421673775
#       policy_loss: -0.006645312532782555
#       total_loss: 53.826072692871094
#       vf_explained_var: 8.285790681838989e-05
#       vf_loss: 53.83182907104492
#     grad_time_ms: 285.679
#     load_time_ms: 8.561
#     num_steps_sampled: 6788
#     num_steps_trained: 6788
#     sample_time_ms: 6870.865
#     update_time_ms: 96.956
#   iterations_since_restore: 6
#   node_ip: 169.237.32.118
#   num_metric_batches_dropped: 0
#   pid: 1154
#   policy_reward_mean: {}
#   time_since_restore: 43.646661043167114
#   time_this_iter_s: 5.5025622844696045
#   time_total_s: 43.646661043167114
#   timestamp: 1556233189
#   timesteps_since_restore: 6788
#   timesteps_this_iter: 1059
#   timesteps_total: 6788
#   training_iteration: 6
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 2/4 CPUs, 0/1 GPUs
# Memory usage on this node: 5.9/33.4 GB
# Result logdir: /headless/ray_results/test
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=1154], 43 s, 6 iter, 6788 ts, 313 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-25_23-00-00
#   done: false
#   episode_len_mean: 350.0
#   episode_reward_max: 489.31080349554145
#   episode_reward_mean: 313.32726548396136
#   episode_reward_min: 133.69298764399164
#   episodes_this_iter: 2
#   episodes_total: 8
#   experiment_id: d54538960e9648069d9a1dea8bd3d931
#   hostname: kronos
#   info:
#     default:
#       cur_kl_coeff: 0.07499999552965164
#       cur_lr: 0.0005000000237487257
#       entropy: 1.3612475395202637
#       kl: 0.02402609772980213
#       policy_loss: -0.0035842135548591614
#       total_loss: 17.864534378051758
#       vf_explained_var: 0.4432656764984131
#       vf_loss: 17.866315841674805
#     grad_time_ms: 265.118
#     load_time_ms: 6.715
#     num_steps_sampled: 9236
#     num_steps_trained: 9236
#     sample_time_ms: 6490.77
#     update_time_ms: 73.949
#   iterations_since_restore: 8
#   node_ip: 169.237.32.118
#   num_metric_batches_dropped: 0
#   pid: 1154
#   policy_reward_mean: {}
#   time_since_restore: 54.77741456031799
#   time_this_iter_s: 8.27556848526001
#   time_total_s: 54.77741456031799
#   timestamp: 1556233200
#   timesteps_since_restore: 9236
#   timesteps_this_iter: 1633
#   timesteps_total: 9236
#   training_iteration: 8
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 2/4 CPUs, 0/1 GPUs
# Memory usage on this node: 5.9/33.4 GB
# Result logdir: /headless/ray_results/test
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=1154], 54 s, 8 iter, 9236 ts, 313 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-25_23-00-06
#   done: false
#   episode_len_mean: 350.0
#   episode_reward_max: 489.31080349554145
#   episode_reward_mean: 323.89000861402775
#   episode_reward_min: 133.69298764399164
#   episodes_this_iter: 1
#   episodes_total: 9
#   experiment_id: d54538960e9648069d9a1dea8bd3d931
#   hostname: kronos
#   info:
#     default:
#       cur_kl_coeff: 0.11249998956918716
#       cur_lr: 0.0005000000237487257
#       entropy: 1.3064906597137451
#       kl: 0.0029544616118073463
#       policy_loss: 7.330104563152418e-05
#       total_loss: 34.25816345214844
#       vf_explained_var: 0.3161628246307373
#       vf_loss: 34.25775909423828
#     grad_time_ms: 260.98
#     load_time_ms: 6.075
#     num_steps_sampled: 10531
#     num_steps_trained: 10531
#     sample_time_ms: 6433.909
#     update_time_ms: 66.354
#   iterations_since_restore: 9
#   node_ip: 169.237.32.118
#   num_metric_batches_dropped: 0
#   pid: 1154
#   policy_reward_mean: {}
#   time_since_restore: 60.996761322021484
#   time_this_iter_s: 6.219346761703491
#   time_total_s: 60.996761322021484
#   timestamp: 1556233206
#   timesteps_since_restore: 10531
#   timesteps_this_iter: 1295
#   timesteps_total: 10531
#   training_iteration: 9
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 2/4 CPUs, 0/1 GPUs
# Memory usage on this node: 5.9/33.4 GB
# Result logdir: /headless/ray_results/test
# RUNNING trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	RUNNING [pid=1154], 60 s, 9 iter, 10531 ts, 324 rew
#
# Result for PPO_MultiWaveAttenuationMergePOEnv-v0_0:
#   custom_metrics: {}
#   date: 2019-04-25_23-00-12
#   done: true
#   episode_len_mean: 350.0
#   episode_reward_max: 529.3599955154474
#   episode_reward_mean: 344.4370073041697
#   episode_reward_min: 133.69298764399164
#   episodes_this_iter: 1
#   episodes_total: 10
#   experiment_id: d54538960e9648069d9a1dea8bd3d931
#   hostname: kronos
#   info:
#     default:
#       cur_kl_coeff: 0.05624999850988388
#       cur_lr: 0.0005000000237487257
#       entropy: 1.2594282627105713
#       kl: 0.007096478249877691
#       policy_loss: -0.004959007725119591
#       total_loss: 59.143497467041016
#       vf_explained_var: 0.0027089864015579224
#       vf_loss: 59.1480598449707
#     grad_time_ms: 253.172
#     load_time_ms: 5.566
#     num_steps_sampled: 11567
#     num_steps_trained: 11567
#     sample_time_ms: 6321.617
#     update_time_ms: 60.321
#   iterations_since_restore: 10
#   node_ip: 169.237.32.118
#   num_metric_batches_dropped: 0
#   pid: 1154
#   policy_reward_mean: {}
#   time_since_restore: 66.5027687549591
#   time_this_iter_s: 5.506007432937622
#   time_total_s: 66.5027687549591
#   timestamp: 1556233212
#   timesteps_since_restore: 11567
#   timesteps_this_iter: 1036
#   timesteps_total: 11567
#   training_iteration: 10
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 0/4 CPUs, 0/1 GPUs
# Memory usage on this node: 5.9/33.4 GB
# Result logdir: /headless/ray_results/test
# TERMINATED trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	TERMINATED [pid=1154], 66 s, 10 iter, 11567 ts, 344 rew
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 0/4 CPUs, 0/1 GPUs
# Memory usage on this node: 5.9/33.4 GB
# Result logdir: /headless/ray_results/test
# TERMINATED trials:
#  - PPO_MultiWaveAttenuationMergePOEnv-v0_0:	TERMINATED [pid=1154], 66 s, 10 iter, 11567 ts, 344 rew
