# %%
from numpy import genfromtxt
import json
import pandas

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
csvpass = '/headless/ray_results/multi_merge/PPO_MultiWaveAttenuationMergePOEnv-v0_0_2019-04-17_06-00-52g_2xwa_e/progress.csv'
df = pandas.read_csv(csvpass)

plt.title('reward mean')
plt.ylabel('reward')
plt.xlabel('episode')
df.episode_reward_mean.plot()
